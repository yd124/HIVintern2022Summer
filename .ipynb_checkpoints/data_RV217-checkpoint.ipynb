# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# https://github.com/dbrvs/AMP-timing

# %%
df = pd.read_csv('RV217Clean.csv') 
df
# Out:
#          ID  draw_date   days       VL  log10VL     VLunit  posVL  \
# 0     10066   4-Feb-10 -589.0      NaN      NaN  copies/mL  False
# 1     10066  18-Feb-10 -575.0      NaN      NaN  copies/mL  False
# 2     10066  22-Jul-10 -421.0      NaN      NaN  copies/mL  False
# 3     10066   6-Jan-11 -253.0      NaN      NaN  copies/mL  False
# 4     10066  23-Jun-11  -85.0      NaN      NaN  copies/mL  False
# ...     ...        ...    ...      ...      ...        ...    ...
# 1481  41146  27-Feb-17    0.0  65476.0      NaN  copies/mL   True
# 1482  41146  10-Mar-17   11.0      NaN      NaN  copies/mL  False
# 1483  41146  24-Mar-17   25.0      NaN      NaN  copies/mL  False
# 1484  41146   3-May-17   65.0      NaN      NaN  copies/mL  False
# 1485  41146   3-Nov-17  249.0      NaN      NaN  copies/mL  False
#
#      primary_kinetics      CD4      CD8  ...  VL_site  FiebigStage  \
# 0               False      NaN      NaN  ...      NaN          NaN
# 1               False      NaN      NaN  ...      NaN          NaN
# 2               False      NaN      NaN  ...      NaN          NaN
# 3               False      NaN      NaN  ...      NaN          NaN
# 4               False      NaN      NaN  ...      NaN          NaN
# ...               ...      ...      ...  ...      ...          ...
# 1481             True   641.19   888.06  ...      NaN         V-VI
# 1482             True  1010.37  1494.53  ...      NaN          NaN
# 1483             True   872.33  1660.31  ...      NaN          NaN
# 1484             True   993.16  1629.42  ...      NaN          NaN
# 1485             True   587.18  1195.85  ...      NaN          NaN
#
#         priority    site  Notes  visit_code  EIA   WB  arv_note  any_arv
# 0     Priority 1  Uganda    NaN           A   NR  NaN       NaN    False
# 1     Priority 1  Uganda    NaN           B   NR  NaN       NaN    False
# 2     Priority 1  Uganda    NaN           D   NR  NaN       NaN    False
# 3     Priority 1  Uganda    NaN           F   NR  NaN       NaN    False
# 4     Priority 1  Uganda    NaN           H   NR  NaN       NaN    False
# ...          ...     ...    ...         ...  ...  ...       ...      ...
# 1481  Priority 4     NaN    NaN           1    R    R       NaN     True
# 1482  Priority 4     NaN    NaN           4  NaN  NaN       NaN     True
# 1483  Priority 4     NaN    NaN          11  NaN  NaN       NaN     True
# 1484  Priority 4     NaN    NaN          13  NaN  NaN       NaN     True
# 1485  Priority 4     NaN    NaN          15  NaN  NaN       NaN     True
#
# [1486 rows x 30 columns]

# %%
df = df[['ID','days', 'log10VL']].dropna()
df
# Out:
#          ID   days  log10VL
# 7     10066    0.0     4.76
# 8     10066    3.0     5.83
# 9     10066    7.0     6.26
# 10    10066   10.0     7.51
# 11    10066   14.0     6.76
# ...     ...    ...      ...
# 1458  40737  333.0     4.89
# 1459  40737  420.0     4.75
# 1461  40737  628.0     1.50
# 1463  40737  826.0     1.50
# 1474  40320    0.0     5.91
#
# [1052 rows x 3 columns]

# %%
df = df.loc[df['days'] < 81]

# %%
patients = df.ID.unique()
patients
# Out:
# array([10066, 10203, 10220, 10428, 10435, 10463, 10723, 10739, 10742,
#        40007, 40061, 40094, 40100, 40123, 40168, 40231, 40250, 40257,
#        40265, 40353, 40363, 40511, 40512, 40577, 10753, 40032, 40211,
#        40503, 40646, 10204, 10374, 10502, 40067, 40096, 40134, 40139,
#        40242, 40283, 40195, 40435, 40492, 40528, 40640, 40652, 40700,
#        40814, 41002, 40436, 40491, 40737, 40320])

# %%
len(patients)
# Out:
# 51

# %%
n = len(patients)
nrows = (n%3+n)//3

fig, axs = plt.subplots(ncols=3,nrows=nrows,figsize=(16,20),tight_layout=True)

for k in range(n):
    ftr = patients[k]    
    
    i = k // 3
    j = k% 3
    
    subdf = df.groupby(['ID']).get_group(ftr)
    x = list(subdf.days)
    axs[i][j].scatter(x,subdf['log10VL'],label=ftr)
    axs[i][j].legend(loc='best')
#     sns.histplot(data=xt, kde=True,ax=axs[i][j])
#     axs[i][j].set_title(ftr)
#     df_train[ftr] = xt   
    
# fig.suptitle("Train Data Graph")
# plt.legend()
plt.show()
